# %%
#Module imports 
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import re 
import seaborn as sns 
import os

# %%
##Preprocessing##
#Read all input files into DataFrames 
formatted_dir = "formatted_input"
bpm_path = "{0}/19isolates_BPM.csv".format(formatted_dir)
mcseed_path = "{0}/19isolates_mcseed_pathwaycomplete.csv".format(formatted_dir)
# dc_tpm_path = "{0}/dc2ndadd_merged_tpm_data.tsv".format(formatted_dir) #Deprecated dataset 
# rob_tpm_path = "{0}/rob3rd_merged_tpm_data.tsv".format(formatted_dir)
# dc_count_path = "{0}/dc2ndadd_merged_count_data.tsv".format(formatted_dir)
# rob_count_path = "{0}/rob3rd_merged_count_data.tsv".format(formatted_dir)
#Flexible whitespace parsing - tpm first column is tab separated then space separated 
# rob_tpm_df = pd.read_csv(rob_tpm_path,sep=r"\s+")
# dc_tpm_df = pd.read_csv(dc_tpm_path,sep=r"\s+")
# rob_count_df = pd.read_csv(rob_count_path,sep=r"\s+")
# dc_count_df = pd.read_csv(dc_count_path,sep=r"\s+")
count_4th_trial_path = "{0}/4thtrial_merged_count_data.tsv".format(formatted_dir)
tpm_4th_trial_path = "{0}/4thtrial_merged_tpm_data.tsv".format(formatted_dir)
count_4t_df = pd.read_csv(count_4th_trial_path,sep=r"\s+")
tpm_4t_df = pd.read_csv(tpm_4th_trial_path,sep=r"\s+")

bpm_df = pd.read_csv(bpm_path)
#Process GO annotations from semicolon separated string into list of entries for columns Functional Pathway and Phenotype
mcseed_df = pd.read_csv(mcseed_path)
for col in ["Functional pathway", "Phenotype"]:
    mcseed_df.loc[:,col] = mcseed_df.loc[:,col].str.split(";")

#Set indices: BPM -> Isolate name; mcseed -> Locus tag; TPM -> target_id (locus)
bpm_df.set_index("Isolate name",inplace=True)
mcseed_df.set_index("Locus tag",inplace=True)
# rob_tpm_df.set_index("target_id",inplace=True)
# dc_tpm_df.set_index("target_id",inplace=True)
# rob_count_df.set_index("target_id",inplace=True)
# dc_count_df.set_index("target_id",inplace=True)
count_4t_df.set_index("target_id",inplace=True)
tpm_4t_df.set_index("target_id",inplace=True)

bpm_df = bpm_df.transpose().drop(index="# functions")
STRAIN_ABBREVS = ["Bbr","Bca","Bli2D9","Blu","Rob","Dfo","Dlo","Eav","Eco","FprB","Lga4B6","Lru","Mmu","Pco","Pst",
                  "Rgn","Rto","Sga","Spa"]
STRAIN_TAGS = dict(zip(bpm_df.columns,STRAIN_ABBREVS))
SHORT_ABBREVS = [abbrev[:3] for abbrev in STRAIN_ABBREVS]
STRAIN_ABBREV_TO_FULL = dict(zip(SHORT_ABBREVS, bpm_df.columns))

for strain in STRAIN_TAGS:
    strain_abbrev = STRAIN_TAGS[strain]
    if not (strain == "Blautia obeum Bg7063_SSTS2015" and strain_abbrev == "Rob"): 
        assert(strain[0] == strain_abbrev[0])

#BPM Summary statistics 
print("BPM=1 pathways by strain")
print(bpm_df.sum())
print("Total BPM=1 pathways: {0}".format(bpm_df.sum().sum()))
# Out:
# BPM=1 pathways by strain
# Isolate name
# Bifidobacterium breve Bgsng463_m5_93            46
# Bifidobacterium catenulatum Bgsng468_m22_84     44
# Bifidobacterium longum infantis 40721_2D9_SN    50
# Blautia luti Bg7063                             53
# Blautia obeum Bg7063_SSTS2015                   53
# Dorea formicigenerans Bg7063                    43
# Dorea longicatena Bg7063                        45
# Enterococcus_avium_Bang_SAM2_39_S1              57
# Escherichia coli PS_131_S11                     77
# Faecalibacterium prausnitzii Bg7063             43
# Lactococcus garvieae Bang155_08_4B6_JG2017      32
# Ligilactobacillus ruminis ATCC_25644            33
# Mitsuokella multacida DSM_20544                 45
# Prevotella copri PS_131_S11                     49
# Prevotella stercorea DSM_18206                  29
# Ruminococcus gnavus M8243_3A11_TMS_2014         63
# Ruminococcus torques Bg7063                     50
# Streptococcus gallolyticus PS_064_S07           42
# Streptococcus pasteriuanus Bang_SAM2_39_S1      47
# dtype: int64
# Total BPM=1 pathways: 901

# %%
#Assertion testing and visual inspection of DFs 
#assert(len(mcseed_df)==len(mcseed_df.index.unique())) #False - locus tags can have multiple entries in mcseed_df, corresponding
#to different subcomponents of same locus; must handle duplicate locus entries in tpm_df 
# assert(len(rob_tpm_df)==len(rob_tpm_df.index.unique()))
# assert(len(dc_tpm_df)==len(dc_tpm_df.index.unique()))
#Concatenate DC and Rob tpm DFs
# tpm_df = pd.concat([dc_tpm_df,rob_tpm_df])
#Concatenate defined community and Rob counts data, convert counts to int 
# count_df = pd.concat([dc_count_df,rob_count_df])
#Sanity checks on concatenated tpm and counts
# assert(len(tpm_df) == (len(rob_tpm_df) + len(dc_tpm_df)))
# assert(len(count_df) == (len(rob_count_df) + len(dc_count_df)))


tpm_df = tpm_4t_df.copy()
count_df = count_4t_df.copy()
# display(tpm_df)
# display(count_df)
#Remove .tpm and .est_counts tags from column names in tpm and count dfs 
tpm_df.columns = tpm_df.columns.str.extract('(.*)\.tpm',expand=False)
count_df.columns = count_df.columns.str.extract('(.*)\.est_counts',expand=False)


assert((tpm_df.columns==count_df.columns).all())
#Filter down to only 1C (Pre-weaning P.copri) and 2A (No P. copri)
samples_1C, samples_2B = [tpm_df.columns.str.contains(tag) for tag in ["1C_Pup","2B_Pup"]] #Boolean arrays 
samples_1C, samples_2B = tpm_df.columns[samples_1C], tpm_df.columns[samples_2B]#Filtered column lists
reordered_cols = pd.Index(list(samples_1C)+list(samples_2B))
print(reordered_cols)
tpm_df, count_df = tpm_df.loc[:,reordered_cols], count_df.loc[:,reordered_cols]
#
count_df_int = count_df.copy()
count_df_int.iloc[:,1:] = count_df_int.iloc[:,1:].astype(int)
#mcseed_df_duplicates = mcseed_df.index[mcseed_df.index.duplicated(keep=False)]

show_tables = True 
if show_tables:
    display(mcseed_df)
    display(tpm_df)
    display(bpm_df)
    
full_dir_path = "formatted_output/4th_trial/full"
if not os.path.exists(full_dir_path):
    os.makedirs(full_dir_path)
overwrite_files = True
if overwrite_files:
    tpm_df.to_csv("{0}/full_merged_tpm.csv".format(full_dir_path))
    count_df.to_csv("{0}/full_merged_count.csv".format(full_dir_path))
    count_df_int.to_csv("{0}/full_merged_count_int.csv".format(full_dir_path))

display(count_df)
# Out:
# Index(['Pup_1-cecal_contents_53_1C_Pup_1', 'Pup_1-ileal_contents_53_1C_Pup_1',
#        'Pup_2-cecal_contents_53_1C_Pup_2', 'Pup_2-ileal_contents_53_1C_Pup_2',
#        'Pup_3-cecal_contents_53_1C_Pup_3', 'Pup_3-ileal_contents_53_1C_Pup_3',
#        'Pup_4-cecal_contents_53_1C_Pup_4', 'Pup_4-ileal_contents_53_1C_Pup_4',
#        'Pup_5-cecal_contents_53_1C_Pup_5', 'Pup_5-ileal_contents_53_1C_Pup_5',
#        'Pup_6-cecal_contents_53_1C_Pup_6', 'Pup_6-ileal_contents_53_1C_Pup_6',
#        'Pup_7-cecal_contents_53_1C_Pup_7', 'Pup_7-ileal_contents_53_1C_Pup_7',
#        'Pup_8-cecal_contents_53_1C_Pup_8', 'Pup_8-ileal_contents_53_1C_Pup_8',
#        'Pup_1-cecal_contents_54_2B_Pup_1', 'Pup_1-ileal_contents_54_2B_Pup_1',
#        'Pup_2-cecal_contents_54_2B_Pup_2', 'Pup_2-ileal_contents_54_2B_Pup_2',
#        'Pup_3-cecal_contents_54_2B_Pup_3', 'Pup_3-ileal_contents_54_2B_Pup_3',
#        'Pup_4-cecal_contents_54_2B_Pup_4', 'Pup_4-ileal_contents_54_2B_Pup_4',
#        'Pup_5-cecal_contents_54_2B_Pup_5', 'Pup_5-ileal_contents_54_2B_Pup_5',
#        'Pup_6-cecal_contents_54_2B_Pup_6', 'Pup_6-ileal_contents_54_2B_Pup_6',
#        'Pup_7-cecal_contents_54_2B_Pup_7', 'Pup_7-ileal_contents_54_2B_Pup_7'],
#       dtype='object')
#                                               Isolate name Protein name  \
# Locus tag
# ANCJAENF_00011        Bifidobacterium breve Bgsng463_m5_93         MalE
# ANCJAENF_00013        Bifidobacterium breve Bgsng463_m5_93         MalF
# ANCJAENF_00014        Bifidobacterium breve Bgsng463_m5_93         MalG
# ANCJAENF_00052        Bifidobacterium breve Bgsng463_m5_93         GalE
# ANCJAENF_00063        Bifidobacterium breve Bgsng463_m5_93         GalE
# ...                                                    ...          ...
# LDOIJNDB_02225  Streptococcus pasteriuanus Bang_SAM2_39_S1       TreB_c
# LDOIJNDB_02226  Streptococcus pasteriuanus Bang_SAM2_39_S1       TreB_b
# LDOIJNDB_02245  Streptococcus pasteriuanus Bang_SAM2_39_S1         GalE
# LDOIJNDB_02252  Streptococcus pasteriuanus Bang_SAM2_39_S1         MetA
# LDOIJNDB_02256  Streptococcus pasteriuanus Bang_SAM2_39_S1         MetN
#
#                                                   Protein product  \
# Locus tag
# ANCJAENF_00011  Maltose/maltodextrin ABC transporter, substrat...
# ANCJAENF_00013  Maltose/maltodextrin ABC transporter, permease...
# ANCJAENF_00014  Maltose/maltodextrin ABC transporter, permease...
# ANCJAENF_00052               UDP-glucose 4-epimerase (EC 5.1.3.2)
# ANCJAENF_00063               UDP-glucose 4-epimerase (EC 5.1.3.2)
# ...                                                           ...
# LDOIJNDB_02225  PTS system, trehalose-specific IIC component (...
# LDOIJNDB_02226  PTS system, trehalose-specific IIB component (...
# LDOIJNDB_02245               UDP-glucose 4-epimerase (EC 5.1.3.2)
# LDOIJNDB_02252     Homoserine O-succinyltransferase (EC 2.3.1.46)
# LDOIJNDB_02256     Methionine ABC transporter ATP-binding protein
#
#                      Functional category  \
# Locus tag
# ANCJAENF_00011  Carbohydrate utilization
# ANCJAENF_00013  Carbohydrate utilization
# ANCJAENF_00014  Carbohydrate utilization
# ANCJAENF_00052  Carbohydrate utilization
# ANCJAENF_00063  Carbohydrate utilization
# ...                                  ...
# LDOIJNDB_02225  Carbohydrate utilization
# LDOIJNDB_02226  Carbohydrate utilization
# LDOIJNDB_02245  Carbohydrate utilization
# LDOIJNDB_02252               Amino acids
# LDOIJNDB_02256               Amino acids
#
#                                                Functional pathway  \
# Locus tag
# ANCJAENF_00011  [maltose utilization,  maltooligosaccharides u...
# ANCJAENF_00013  [maltose utilization,  maltooligosaccharides u...
# ANCJAENF_00014  [maltose utilization,  maltooligosaccharides u...
# ANCJAENF_00052      [galactose utilization,  lactose utilization]
# ANCJAENF_00063      [galactose utilization,  lactose utilization]
# ...                                                           ...
# LDOIJNDB_02225                            [trehalose utilization]
# LDOIJNDB_02226                            [trehalose utilization]
# LDOIJNDB_02245      [galactose utilization,  lactose utilization]
# LDOIJNDB_02252                          [methionine biosynthesis]
# LDOIJNDB_02256                          [methionine biosynthesis]
#
#                      Phenotype
# Locus tag
# ANCJAENF_00011  [Mal,  (Mal)n]
# ANCJAENF_00013  [Mal,  (Mal)n]
# ANCJAENF_00014  [Mal,  (Mal)n]
# ANCJAENF_00052     [Gal,  Lac]
# ANCJAENF_00063     [Gal,  Lac]
# ...                        ...
# LDOIJNDB_02225           [Tre]
# LDOIJNDB_02226           [Tre]
# LDOIJNDB_02245     [Gal,  Lac]
# LDOIJNDB_02252           [Met]
# LDOIJNDB_02256           [Met]
#
# [6704 rows x 6 columns]
#                 Pup_1-cecal_contents_53_1C_Pup_1  \
# target_id
# ANCJAENF_00001                        678.600000
# ANCJAENF_00002                       6196.870000
# ANCJAENF_00003                        678.600000
# ANCJAENF_00004                       6196.870000
# ANCJAENF_00005                          6.251760
# ...                                          ...
# LDOIJNDB_02259                          0.000000
# LDOIJNDB_02260                          1.411490
# LDOIJNDB_02261                         63.744900
# LDOIJNDB_02262                          0.946617
# LDOIJNDB_02263                         25.690700
#
#                 Pup_1-ileal_contents_53_1C_Pup_1  \
# target_id
# ANCJAENF_00001                          20.97070
# ANCJAENF_00002                         124.49900
# ANCJAENF_00003                          20.97070
# ANCJAENF_00004                         124.49900
# ANCJAENF_00005                           0.00000
# ...                                          ...
# LDOIJNDB_02259                           6.27988
# LDOIJNDB_02260                           0.00000
# LDOIJNDB_02261                          59.79710
# LDOIJNDB_02262                           1.37405
# LDOIJNDB_02263                           6.89498
#
#                 Pup_2-cecal_contents_53_1C_Pup_2  \
# target_id
# ANCJAENF_00001                        167.432000
# ANCJAENF_00002                       1705.060000
# ANCJAENF_00003                        167.432000
# ANCJAENF_00004                       1705.060000
# ANCJAENF_00005                          0.554181
# ...                                          ...
# LDOIJNDB_02259                          0.000000
# LDOIJNDB_02260                          5.109380
# LDOIJNDB_02261                        184.225000
# LDOIJNDB_02262                          3.146830
# LDOIJNDB_02263                         78.220400
#
#                 Pup_2-ileal_contents_53_1C_Pup_2  \
# target_id
# ANCJAENF_00001                          9.825210
# ANCJAENF_00002                         59.888400
# ANCJAENF_00003                          9.825210
# ANCJAENF_00004                         59.888400
# ANCJAENF_00005                          0.000000
# ...                                          ...
# LDOIJNDB_02259                          0.000000
# LDOIJNDB_02260                          0.000000
# LDOIJNDB_02261                        173.775000
# LDOIJNDB_02262                          0.450998
# LDOIJNDB_02263                         45.914800
#
#                 Pup_3-cecal_contents_53_1C_Pup_3  \
# target_id
# ANCJAENF_00001                        715.706000
# ANCJAENF_00002                       9143.190000
# ANCJAENF_00003                        715.706000
# ANCJAENF_00004                       9143.190000
# ANCJAENF_00005                          3.599670
# ...                                          ...
# LDOIJNDB_02259                          0.000000
# LDOIJNDB_02260                          4.975030
# LDOIJNDB_02261                        109.157000
# LDOIJNDB_02262                          0.750576
# LDOIJNDB_02263                         45.793800
#
#                 Pup_3-ileal_contents_53_1C_Pup_3  \
# target_id
# ANCJAENF_00001                      3.465060e+01
# ANCJAENF_00002                      1.574560e+02
# ANCJAENF_00003                      3.465060e+01
# ANCJAENF_00004                      1.574560e+02
# ANCJAENF_00005                      9.038230e-02
# ...                                          ...
# LDOIJNDB_02259                      5.026050e-09
# LDOIJNDB_02260                      4.114010e-01
# LDOIJNDB_02261                      4.862450e+01
# LDOIJNDB_02262                      9.599220e-01
# LDOIJNDB_02263                      1.699150e+01
#
#                 Pup_4-cecal_contents_53_1C_Pup_4  \
# target_id
# ANCJAENF_00001                        1534.45000
# ANCJAENF_00002                       13517.20000
# ANCJAENF_00003                        1534.45000
# ANCJAENF_00004                       13517.20000
# ANCJAENF_00005                           3.17250
# ...                                          ...
# LDOIJNDB_02259                           0.00000
# LDOIJNDB_02260                           5.10357
# LDOIJNDB_02261                         114.33300
# LDOIJNDB_02262                           1.18046
# LDOIJNDB_02263                          28.32190
#
#                 Pup_4-ileal_contents_53_1C_Pup_4  \
# target_id
# ANCJAENF_00001                         23.051100
# ANCJAENF_00002                        126.393000
# ANCJAENF_00003                         23.051100
# ANCJAENF_00004                        126.393000
# ANCJAENF_00005                          0.000000
# ...                                          ...
# LDOIJNDB_02259                         22.167900
# LDOIJNDB_02260                          0.842406
# LDOIJNDB_02261                        138.692000
# LDOIJNDB_02262                          0.142805
# LDOIJNDB_02263                         27.763400
#
#                 Pup_5-cecal_contents_53_1C_Pup_5  \
# target_id
# ANCJAENF_00001                       1631.420000
# ANCJAENF_00002                      14086.200000
# ANCJAENF_00003                       1631.420000
# ANCJAENF_00004                      14086.200000
# ANCJAENF_00005                          0.796541
# ...                                          ...
# LDOIJNDB_02259                          0.000000
# LDOIJNDB_02260                          2.567400
# LDOIJNDB_02261                        135.114000
# LDOIJNDB_02262                          1.885920
# LDOIJNDB_02263                         31.946300
#
#                 Pup_5-ileal_contents_53_1C_Pup_5  ...  \
# target_id                                         ...
# ANCJAENF_00001                          50.70230  ...
# ANCJAENF_00002                         312.95700  ...
# ANCJAENF_00003                          50.70230  ...
# ANCJAENF_00004                         312.95700  ...
# ANCJAENF_00005                           0.00000  ...
# ...                                          ...  ...
# LDOIJNDB_02259                           2.41611  ...
# LDOIJNDB_02260                           0.00000  ...
# LDOIJNDB_02261                         172.26000  ...
# LDOIJNDB_02262                           1.10349  ...
# LDOIJNDB_02263                          42.14460  ...
#
#                 Pup_3-cecal_contents_54_2B_Pup_3  \
# target_id
# ANCJAENF_00001                          3.799670
# ANCJAENF_00002                         36.250800
# ANCJAENF_00003                          3.799670
# ANCJAENF_00004                         36.250800
# ANCJAENF_00005                          0.000000
# ...                                          ...
# LDOIJNDB_02259                          0.000000
# LDOIJNDB_02260                          0
# ANCJAENF_00005                          0.000000
# ...                                          ...
# LDOIJNDB_02259                          0.000000
# LDOIJNDB_02260                         10.036100
# LDOIJNDB_02261                         65.596400
# LDOIJNDB_02262                          3.550830
# LDOIJNDB_02263                          6.938070
#
#                 Pup_7-cecal_contents_54_2B_Pup_7  \
# target_id
# ANCJAENF_00001                        153.265000
# ANCJAENF_00002                       1150.030000
# ANCJAENF_00003                        153.265000
# ANCJAENF_00004                       1150.030000
# ANCJAENF_00005                          0.591864
# ...                                          ...
# LDOIJNDB_02259                          0.000000
# LDOIJNDB_02260                          3.149660
# LDOIJNDB_02261                        168.805000
# LDOIJNDB_02262                          2.036340
# LDOIJNDB_02263                         86.280500
#
#                 Pup_7-ileal_contents_54_2B_Pup_7
# target_id
# ANCJAENF_00001                          0.881001
# ANCJAENF_00002                          4.975310
# ANCJAENF_00003                          0.881001
# ANCJAENF_00004                          4.975310
# ANCJAENF_00005                          0.000000
# ...                                          ...
# LDOIJNDB_02259                          8.712830
# LDOIJNDB_02260                          0.000000
# LDOIJNDB_02261                        218.904000
# LDOIJNDB_02262                          0.063649
# LDOIJNDB_02263                          6.436220
#
# [48390 rows x 30 columns]
# Isolate name  Bifidobacterium breve Bgsng463_m5_93  \
# Glc                                              1
# Gal                                              0
# Fru                                              1
# Man                                              0
# Tag                                              0
# ...                                            ...
# Lys_d                                            0
# Met_d                                            0
# Pro_d                                            0
# Thr_d                                            0
# Trp_d                                            0
#
# Isolate name  Bifidobacterium catenulatum Bgsng468_m22_84  \
# Glc                                                     1
# Gal                                                     0
# Fru                                                     1
# Man                                                     0
# Tag                                                     0
# ...                                                   ...
# Lys_d                                                   0
# Met_d                                                   0
# Pro_d                                                   0
# Thr_d                                                   0
# Trp_d                                                   0
#
# Isolate name  Bifidobacterium longum infantis 40721_2D9_SN  \
# Glc                                                      1
# Gal                                                      1
# Fru                                                      1
# Man                                                      0
# Tag                                                      0
# ...                                                    ...
# Lys_d                                                    0
# Met_d                                                    1
# Pro_d                                                    0
# Thr_d                                                    0
# Trp_d                                                    0
#
# Isolate name  Blautia luti Bg7063  Blautia obeum Bg7063_SSTS2015  \
# Glc                             1                              1
# Gal                             0                              0
# Fru                             1                              0
# Man                             0                              0
# Tag                             0                              0
# ...                           ...                            ...
# Lys_d                           0                              0
# Met_d                           0                              0
# Pro_d                           0                              0
# Thr_d                           0                              0
# Trp_d                           0                              0
#
# Isolate name  Dorea formicigenerans Bg7063  Dorea longicatena Bg7063  \
# Glc                                      0                         1
# Gal                                      1                         1
# Fru                                      0                         1
# Man                                      0                         0
# Tag                                      0                         0
# ...                                    ...                       ...
# Lys_d                                    0                         0
# Met_d                                    1                         0
# Pro_d                                    0                         0
# Thr_d                                    0                         1
# Trp_d                                    0                         0
#
# Isolate name  Enterococcus_avium_Bang_SAM2_39_S1  Escherichia coli PS_131_S11  \
# Glc                                            1                            1
# Gal                                            1                            1
# Fru                                            1                            1
# Man                                            1                            1
# Tag                                            1                            0
# ...                                          ...                          ...
# Lys_d                                          0                            1
# Met_d                                          0                            0
# Pro_d                                          0                            1
# Thr_d                                          1                            1
# Trp_d                                          0                            1
#
# Isolate name  Faecalibacterium prausnitzii Bg7063  \
# Glc                                             1
# Gal                                             1
# Fru                                             1
# Man                                             0
# Tag                                             0
# ...                                           ...
# Lys_d                                           0
# Met_d                                           0
# Pro_d                                           0
# Thr_d                                           0
# Trp_d                                           0
#
# Isolate name  Lactococcus garvieae Bang155_08_4B6_JG2017  \
# Glc                                                    1
# Gal                                                    0
# Fru                                                    1
# Man                                                    1
# Tag                                                    0
# ...                                                  ...
# Lys_d                                                  0
# Met_d                                                  0
# Pro_d                                                  0
# Thr_d                                                  1
# Trp_d                                                  0
#
# Isolate name  Ligilactobacillus ruminis ATCC_25644  \
# Glc                                              1
# Gal                                              0
# Fru                                              1
# Man                                              1
# Tag                                              0
# ...                                            ...
# Lys_d                                            0
# Met_d                                            0
# Pro_d                                            0
# Thr_d                                            0
# Trp_d                                            0
#
# Isolate name  Mitsuokella multacida DSM_20544  Prevotella copri PS_131_S11  \
# Glc                                         1                            1
# Gal                                         0                            1
# Fru                                         1                            1
# Man                                         1                            0
# Tag                                         0                            0
# ...                                       ...                          ...
# Lys_d                                       0                            0
# Met_d                                       0                            0
# Pro_d                                       0                            0
# Thr_d                                       0                            0
# Trp_d                                       0                            0
#
# Isolate name  Prevotella stercorea DSM_18206  \
# Glc                                        1
# Gal                                        1
# Fru                                        1
# Man                                        0
# Tag                                        0
# ...                                      ...
# Lys_d                                      0
# Met_d                                      0
# Pro_d                                      0
# Thr_d                                      1
# Trp_d                                      0
#
# Isolate name  Ruminococcus gnavus M8243_3A11_TMS_2014  \
# Glc                                                 1
# Gal                                                 0
# Fru                                                 1
# Man                                                 0
# Tag                                                 0
# ...                                               ...
# Lys_d                                               0
# Met_d                                               0
# Pro_d                                               0
# Thr_d                                               0
# Trp_d                                               1
#
# Isolate name  Ruminococcus torques Bg7063  \
# Glc                                     1
# Gal                                     0
# Fru                                     1
# Man                                     0
# Tag                                     0
# ...                                   ...
# Lys_d                                   0
# Met_d                                   0
# Pro_d                                   0
# Thr_d                                   0
# Trp_d                                   0
#
# Isolate name  Streptococcus gallolyticus PS_064_S07  \
# Glc                                               1
# Gal                                               0
# Fru                                               1
# Man                                               1
# Tag                                               0
# ...                                             ...
# Lys_d                                             0
# Met_d                                             0
# Pro_d                                             0
# Thr_d                                             0
# Trp_d                                             0
#
# Isolate name  Streptococcus pasteriuanus Bang_SAM2_39_S1
# Glc                                                    1
# Gal                                                    1
# Fru                                                    1
# Man                                                    1
# Tag                                                    1
# ...                                                  ...
# Lys_d                                                  0
# Met_d                                                  0
# Pro_d                                                  0
# Thr_d                                                  0
# Trp_d                                                  0
#
# [106 rows x 19 columns]
#                 Pup_1-cecal_contents_53_1C_Pup_1  \
# target_id
# ANCJAENF_00001                      31592.600000
# ANCJAENF_00002                     614048.000000
# ANCJAENF_00003                      31592.600000
# ANCJAENF_00004                     614048.000000
# ANCJAENF_00005                         19.000000
# ...                                          ...
# LDOIJNDB_02259                          0.000000
# LDOIJNDB_02260                          0.285714
# LDOIJNDB_02261                       5997.760000
# LDOIJNDB_02262                          2.062500
# LDOIJNDB_02263                       1212.100000
#
#                 Pup_1-ileal_contents_53_1C_Pup_1  \
# target_id
# ANCJAENF_00001                         2852.4500
# ANCJAENF_00002                        36221.9000
# ANCJAENF_00003                         2852.4500
# ANCJAENF_00004                        36221.9000
# ANCJAENF_00005                            0.0000
# ANCJAENF_00005                          0.000000
# ...                                          ...
# LDOIJNDB_02259                         65.345600
# LDOIJNDB_02260                          0.285714
# LDOIJNDB_02261                      21638.000000
# LDOIJNDB_02262                          0.437500
# LDOIJNDB_02263                       2158.810000
#
#                 Pup_5-cecal_contents_53_1C_Pup_5  \
# target_id
# ANCJAENF_00001                      6.397330e+04
# ANCJAENF_00002                      1.178570e+06
# ANCJAENF_00003                      6.397330e+04
# ANCJAENF_00004                      1.178570e+06
# ANCJAENF_00005                      2.000000e+00
# ...                                          ...
# LDOIJNDB_02259                      0.000000e+00
# LDOIJNDB_02260                      4.285710e-01
# LDOIJNDB_02261                      1.073310e+04
# LDOIJNDB_02262                      2.687500e+00
# LDOIJNDB_02263                      1.269610e+03
#
#                 Pup_5-ileal_contents_53_1C_Pup_5  ...  \
# target_id                                         ...
# ANCJAENF_00001                        3300.96000  ...
# ANCJAENF_00002                       43596.60000  ...
# ANCJAENF_00003                        3300.96000  ...
# ANCJAENF_00004                       43596.60000  ...
# ANCJAENF_00005                           0.00000  ...
# ...                                          ...  ...
# LDOIJNDB_02259                           6.05787  ...
# LDOIJNDB_02260                           0.00000  ...
# LDOIJNDB_02261                       22780.20000  ...
# LDOIJNDB_02262                           2.87500  ...
# LDOIJNDB_02263                        2781.01000  ...
#
#                 Pup_3-cecal_contents_54_2B_Pup_3  \
# target_id
# ANCJAENF_00001                        427.762000
# ANCJAENF_00002                       8698.240000
# ANCJAENF_00003                        427.762000
# ANCJAENF_00004                       8698.240000
# ANCJAENF_00005                          0.000000
# ...                                          ...
# LDOIJNDB_02259                          0.000000
# LDOIJNDB_02260                          0.285714
# LDOIJNDB_02261                      11591.400000
# LDOIJNDB_02262                          1.062500
# LDOIJNDB_02263                        963.197000
#
#                 Pup_3-ileal_contents_54_2B_Pup_3  \
# target_id
# ANCJAENF_00001                          202.3200
# ANCJAENF_00002                         1344.3600
# ANCJAENF_00003                          202.3200
# ANCJAENF_00004                         1344.3600
# ANCJAENF_00005                            0.0000
# ...                                          ...
# LDOIJNDB_02259                           54.3603
# LDOIJNDB_02260                            0.0000
# LDOIJNDB_02261                        20421.6000
# LDOIJNDB_02262                            2.8804
# LDOIJNDB_02263                          933.2980
#
#                 Pup_4-cecal_contents_54_2B_Pup_4  \
# target_id
# ANCJAENF_00001                          10.47990
# ANCJAENF_00002                         200.07000
# ANCJAENF_00003                          10.47990
# ANCJAENF_00004                         200.07000
# ANCJAENF_00005                           0.00000
# ...                                          ...
# LDOIJNDB_02259                           0.00000
# LDOIJNDB_02260                           1.14286
# LDOIJNDB_02261                       17391.40000
# LDOIJNDB_02262                           4.50000
# LDOIJNDB_02263                        2247.05000
#
#                 Pup_4-ileal_contents_54_2B_Pup_4  \
# target_id
# ANCJAENF_00001                         14.633800
# ANCJAENF_00002                        884.377000
# ANCJAENF_00003                         14.633800
# ANCJAENF_00004                        884.377000
# ANCJAENF_00005                          0.000000
# ...                                          ...
# LDOIJNDB_02259                          1.266000
# LDOIJNDB_02260                          0.571429
# LDOIJNDB_02261                      18417.500000
# LDOIJNDB_02262                          4.267950
# LDOIJNDB_02263                       1225.380000
#
#                 Pup_5-cecal_contents_54_2B_Pup_5  \
# target_id
# ANCJAENF_00001                       10404.10000
# ANCJAENF_00002                      185254.00000
# ANCJAENF_00003                       10404.10000
# ANCJAENF_00004                      185254.00000
# ANCJAENF_00005                          15.00000
# ...                                          ...
# LDOIJNDB_02259                           0.00000
# LDOIJNDB_02260                           7.85714
# LDOIJNDB_02261                       22426.50000
# LDOIJNDB_02262                          20.25000
# LDOIJNDB_02263                        2965.06000
#
#                 Pup_5-ileal_contents_54_2B_Pup_5  \
# target_id
# ANCJAENF_00001                           1370.69
# ANCJAENF_00002                          14274.50
# ANCJAENF_00003                           1370.69
# ANCJAENF_00004                          14274.50
# ANCJAENF_00005                              0.00
# ...                                          ...
# LDOIJNDB_02259                              0.00
# LDOIJNDB_02260                              0.00
# LDOIJNDB_02261                          11028.90
# LDOIJNDB_02262                              3.75
# LDOIJNDB_02263                           1226.39
#
#                 Pup_6-cecal_contents_54_2B_Pup_6  \
# target_id
# ANCJAENF_00001                       20874.30000
# ANCJAENF_00002                      363192.00000
# ANCJAENF_00003                       20874.30000
# ANCJAENF_00004                      363192.00000
# ANCJAENF_00005                           0.00000
# ...                                          ...
# LDOIJNDB_02259                           0.00000
# LDOIJNDB_02260                           2.14286
# LDOIJNDB_02261                      145913.00000
# LDOIJNDB_02262                           4.31250
# LDOIJNDB_02263                       40133.90000
#
#                 Pup_6-ileal_contents_54_2B_Pup_6  \
# target_id
# ANCJAENF_00001                          51.33900
# ANCJAENF_00002                         577.35000
# ANCJAENF_00003                          51.33900
# ANCJAENF_00004                         577.35000
# ANCJAENF_00005                           0.00000
# ...                                          ...
# LDOIJNDB_02259                           0.00000
# LDOIJNDB_02260                           8.85714
# LDOIJNDB_02261                       27970.50000
# LDOIJNDB_02262                          25.06250
# LDOIJNDB_02263                        1477.24000
#
#                 Pup_7-cecal_contents_54_2B_Pup_7  \
# target_id
# ANCJAENF_00001                       20041.30000
# ANCJAENF_00002                      319494.00000
# ANCJAENF_00003                       20041.30000
# ANCJAENF_00004                      319494.00000
# ANCJAENF_00005                           5.00000
# ...                                          ...
# LDOIJNDB_02259                           0.00000
# LDOIJNDB_02260                           1.71429
# LDOIJNDB_02261                       44534.00000
# LDOIJNDB_02262                          10.68750
# LDOIJNDB_02263                       11433.20000
#
#                 Pup_7-ileal_contents_54_2B_Pup_7
# target_id
# ANCJAENF_00001                          121.7910
# ANCJAENF_00002                         1471.7700
# ANCJAENF_00003                          121.7910
# ANCJAENF_00004                         1471.7700
# ANCJAENF_00005                            0.0000
# ...                                          ...
# LDOIJNDB_02259                           58.0740
# LDOIJNDB_02260                            0.0000
# LDOIJNDB_02261                        61472.0000
# LDOIJNDB_02262                            0.4375
# LDOIJNDB_02263                          901.8180
#
# [48390 rows x 30 columns]

# %%
cecal_abundance_path = "formatted_input/cecal_abundance.csv"
cecal_abundance_df = pd.read_csv(cecal_abundance_path,sep=",",index_col="MouseID")
cecal_abundance_df.columns = [col.strip() for col in cecal_abundance_df.columns]
# display(cecal_abundance_df)

ABUNDANCE_SCALING_FACTOR = 10**7

STRAIN_ABBREVS = ["Bbr","Bca","Bli463","Bli2D9","Blu","Rob","Dfo","Dlo","Eav","Eco","FprB","Lga4B6","Lru","Mmu","Pco","Pst",
                  "Rgn","Rto","Sga","Spa"]
bact_columns = [col.strip() for col in cecal_abundance_df.columns[3:-1].values]
abbrevs_map = dict(zip(bact_columns,STRAIN_ABBREVS))

cecal_abundance_df = cecal_abundance_df.rename(columns=abbrevs_map)
cecal_abundance_converted  = cecal_abundance_df.copy()
cecal_abundance_converted = cecal_abundance_converted.replace("ND",0)
cecal_abundance_converted.loc[:,STRAIN_ABBREVS] = cecal_abundance_converted.loc[:,STRAIN_ABBREVS].astype(float)

for col in STRAIN_ABBREVS:
    cecal_abundance_converted.loc[:,col] = np.power(cecal_abundance_converted.loc[:,col].values,
                                                    [10]*len(cecal_abundance_converted))
    cecal_abundance_converted.loc[:,col] = cecal_abundance_converted.loc[:,col]/(ABUNDANCE_SCALING_FACTOR) #Scale by millions of genome equivalents 

#Drop 1B samples from cecal_abundance 
sample_arm_re=r'[\w_]+[\w_]+_([12][ABC])_[\w+]'
cecal_abundance_converted.loc[:,"Arm"] = cecal_abundance_converted.index.str.extract(sample_arm_re,expand=False)
cecal_abundance_converted = cecal_abundance_converted.loc[~(cecal_abundance_converted["Arm"]=="1B"),:]
with pd.option_context('display.max_columns',None):
    display(cecal_abundance_converted)
# cecal_abundance_converted = cecal_abundance_converted.loc[]
# Out:
#                                                                   Treatment  \
# MouseID
# Pup_1-cecal_contents_53_1C_Pup_1  Arm 1 (Pre-weaning P. copri colonization)
# Pup_2-cecal_contents_53_1C_Pup_2  Arm 1 (Pre-weaning P. copri colonization)
# Pup_3-cecal_contents_53_1C_Pup_3  Arm 1 (Pre-weaning P. copri colonization)
# Pup_4-cecal_contents_53_1C_Pup_4  Arm 1 (Pre-weaning P. copri colonization)
# Pup_5-cecal_contents_53_1C_Pup_5  Arm 1 (Pre-weaning P. copri colonization)
# Pup_6-cecal_contents_53_1C_Pup_6  Arm 1 (Pre-weaning P. copri colonization)
# Pup_7-cecal_contents_53_1C_Pup_7  Arm 1 (Pre-weaning P. copri colonization)
# Pup_8-cecal_contents_53_1C_Pup_8  Arm 1 (Pre-weaning P. copri colonization)
# Pup_1-cecal_contents_54_2B_Pup_1           Arm 3 (No P. copri colonization)
# Pup_2-cecal_contents_54_2B_Pup_2           Arm 3 (No P. copri colonization)
# Pup_3-cecal_contents_54_2B_Pup_3           Arm 3 (No P. copri colonization)
# Pup_4-cecal_contents_54_2B_Pup_4           Arm 3 (No P. copri colonization)
# Pup_5-cecal_contents_54_2B_Pup_5           Arm 3 (No P. copri colonization)
# Pup_6-cecal_contents_54_2B_Pup_6           Arm 3 (No P. copri colonization)
# Pup_7-cecal_contents_54_2B_Pup_7           Arm 3 (No P. copri colonization)
#
#                                   Mouse Number     Sex        Bbr        Bca  \
# MouseID
# Pup_1-cecal_contents_53_1C_Pup_1             1  female   5.655390   9.094947
# Pup_2-cecal_contents_53_1C_Pup_2             2    male   1.850428   6.462036
# Pup_3-cecal_contents_53_1C_Pup_3             3    male   8.667700  24.109723
# Pup_4-cecal_contents_53_1C_Pup_4             4    male   9.541056  25.917595
# Pup_5-cecal_contents_53_1C_Pup_5             5  female  12.270399  32.552436
# Pup_6-cecal_contents_53_1C_Pup_6             6    male  17.168893  42.976258
# Pup_7-cecal_contents_53_1C_Pup_7             7    male  10.492829  26.674261
# Pup_8-cecal_contents_53_1C_Pup_8             8  female   8.529351  25.546555
#
#                                        Sga        Spa  Total Bacterial Load  \
# MouseID
# Pup_1-cecal_contents_53_1C_Pup_1  2.674554   5.287094                  7.75
# Pup_2-cecal_contents_53_1C_Pup_2  2.269807   4.536131                  7.48
# Pup_3-cecal_contents_53_1C_Pup_3  2.926456   8.392994                  7.82
# Pup_4-cecal_contents_53_1C_Pup_4  2.579384   7.866963                  7.85
# Pup_5-cecal_contents_53_1C_Pup_5  0.231675   8.808064                  7.91
# Pup_6-cecal_contents_53_1C_Pup_6  0.690989  15.922622                  8.03
# Pup_7-cecal_contents_53_1C_Pup_7  1.652366  14.314543                  8.04
# Pup_8-cecal_contents_53_1C_Pup_8  2.108325  22.746036                  8.07
# Pup_1-cecal_contents_54_2B_Pup_1  0.584704  26.674261                  8.22
# Pup_2-cecal_contents_54_2B_Pup_2  0.016270   3.882567                  7.95
# Pup_3-cecal_contents_54_2B_Pup_3  0.035559   6.355842                  8.09
# Pup_4-cecal_contents_54_2B_Pup_4  0.006966   5.025195                  7.61
# Pup_5-cecal_contents_54_2B_Pup_5  0.560546  49.909369                  8.63
# Pup_6-cecal_contents_54_2B_Pup_6  0.066166  22.416150                  7.84
# Pup_7-cecal_contents_54_2B_Pup_7  0.130988  17.691499                  7.97
#
#                                  Arm
# MouseID
# Pup_1-cecal_contents_53_1C_Pup_1  1C
# Pup_2-cecal_contents_53_1C_Pup_2  1C
# Pup_3-cecal_contents_53_1C_Pup_3  1C
# Pup_4-cecal_contents_53_1C_Pup_4  1C
# Pup_5-cecal_contents_53_1C_Pup_5  1C
# Pup_6-cecal_contents_53_1C_Pup_6  1C
# Pup_7-cecal_contents_53_1C_Pup_7  1C
# Pup_8-cecal_contents_53_1C_Pup_8  1C
# Pup_1-cecal_contents_54_2B_Pup_1  2B
# Pup_2-cecal_contents_54_2B_Pup_2  2B
# Pup_3-cecal_contents_54_2B_Pup_3  2B
# Pup_4-cecal_contents_54_2B_Pup_4  2B
# Pup_5-cecal_contents_54_2B_Pup_5  2B
# Pup_6-cecal_contents_54_2B_Pup_6  2B
# Pup_7-cecal_contents_54_2B_Pup_7  2B

# %%
def vc_strain_locus_tag(expr_df,mcseed_df):
    """Returns a DataFrame indexed on locus tags for each strain, containing columns: 
        "Filtered Loci" - number of loci corresponding to that locus tag (ie loci per strain)
        "Strain" - full strain name corresponding to locus tag 
        :param pd.DataFrame expr_df: DataFrame indexed by ORFs containing (transformed) expression data, columns
        are samples 
        :param pd.DataFrame mcseed_df: DataFrame containing mcSEED annotations for loci, not necessarily for 
        all loci in expr_df 
    """
    vc_by_strain_locus_tag = expr_df.index.str.extract(r'(\w+)_\d+',expand=False).value_counts()
#     vc_by_strain_locus_tag.drop("ROSSTS7063_a2",inplace=True) #2nd3rd_trial specific error 
    locus_tag_strains = [mcseed_df.loc[mcseed_df.index.str.contains(lt),"Isolate name"].values[0] 
                             for lt in vc_by_strain_locus_tag.index] #if lt != "ROSSTS7063_a2"]
    locus_vc_df = pd.DataFrame(index=vc_by_strain_locus_tag.index,columns=["Filtered Loci","Strain"])
    locus_vc_df.loc[:,"Filtered Loci"] = vc_by_strain_locus_tag
    locus_vc_df.loc[:,"Strain"] = locus_tag_strains
    locus_vc_df.loc[:,"Abbreviation"] = [STRAIN_TAGS[lts] for lts in locus_tag_strains]
    return locus_vc_df

def abundance_correct_expr_df(expr_df,abundance_df,locus_vc_df):
    abundance_corrected = expr_df.copy()
    abundance_corrected = abundance_corrected.loc[:,abundance_corrected.columns.isin(abundance_df.index)]
    abundance_corrected.loc[:,"Locus Tag"] = abundance_corrected.index.str.extract(r'(\w+)_\d+',expand=False)
    for lt in abundance_corrected["Locus Tag"].unique():
        strain_abbrev = locus_vc_df.loc[lt,"Abbreviation"]
        lt_expr_df = abundance_corrected.loc[abundance_corrected.loc[:,"Locus Tag"]==lt]
        abundance_data = abundance_df.loc[:,strain_abbrev]
        samples = list(abundance_data.index)
#         print(samples)
        lt_ac = lt_expr_df.loc[:,lt_expr_df.columns.isin(samples)]/abundance_data
        abundance_corrected.loc[lt_ac.index,samples] = lt_ac.loc[:,samples]
    abundance_corrected.drop(columns="Locus Tag",inplace=True)
#     display(abundance_corrected.loc[np.isinf(abundance_corrected).any(axis=1),:])
    abundance_corrected.replace([np.inf, -np.inf], np.nan, inplace=True)

    abundance_corrected.replace(np.nan,0,inplace=True)
    abundance_corrected = abundance_corrected.astype('float')
    return abundance_corrected
    
locus_vc_df = vc_strain_locus_tag(count_df,mcseed_df)
# display(locus_vc_df)
abundance_corrected_expr = abundance_correct_expr_df(count_df,cecal_abundance_converted,locus_vc_df)
assert(len(count_df.loc[count_df.isna().any(axis=1)])==0)
assert(len(abundance_corrected_expr.loc[abundance_corrected_expr.isna().any(axis=1)])==0)
abundance_corrected_expr_int = np.floor(abundance_corrected_expr)
abundance_corrected_expr_int = abundance_corrected_expr_int.astype('int')
display(abundance_corrected_expr)
display(abundance_corrected_expr_int)

filt_tpm = tpm_df.loc[:,tpm_df.columns.isin(abundance_corrected_expr.columns)]
# display(filt_tpm)

full_dir_path = "formatted_output/4th_trial/full"
if not os.path.exists(full_dir_path):
    os.makedirs(full_dir_path)
overwrite_files = True
if overwrite_files or not os.path.exists("{0}/abundance_corrected_count.csv".format(full_dir_path)):
    abundance_corrected_expr.to_csv("{0}/abundance_corrected_count.csv".format(full_dir_path))
    abundance_corrected_expr_int.to_csv("{0}/abundance_corrected_count_int.csv".format(full_dir_path))
    filt_tpm.to_csv("{0}/column_filtered_tpm.csv".format(full_dir_path))
# Out:
#                 Pup_1-cecal_contents_53_1C_Pup_1  \
# target_id
# ANCJAENF_00001                       5586.280919
# ANCJAENF_00002                     108577.471494
# ANCJAENF_00003                       5586.280919
# ANCJAENF_00004                     108577.471494
# ANCJAENF_00005                          3.359627
# ...                                          ...
# LDOIJNDB_02259                          0.000000
# LDOIJNDB_02260                          0.054040
# LDOIJNDB_02261                       1134.415146
# LDOIJNDB_02262                          0.390101
# LDOIJNDB_02263                        229.256355
#
#                 Pup_2-cecal_contents_53_1C_Pup_2  \
# target_id
# ANCJAENF_00001                       5174.323037
# ANCJAENF_00002                     112351.330834
# ANCJAENF_00003                       5174.323037
# ANCJAENF_00004                     112351.330834
# ANCJAENF_00005                          1.080831
# ...                                          ...
# LDOIJNDB_02259                          0.000000
# LDOIJNDB_02260                          0.283438
# LDOIJNDB_02261                       4701.650370
# LDOIJNDB_02262                          1.484289
# LDOIJNDB_02263                        999.387016
#
#                 Pup_3-cecal_contents_53_1C_Pup_3  \
# target_id
# ANCJAENF_00001                       3244.251830
# ANCJAENF_00002                      88399.926539
# ANCJAENF_00003                       3244.251830
# ANCJAENF_00004                      88399.926539
# ANCJAENF_00005                          1.038338
# ...                                          ...
# LDOIJNDB_02259                          0.000000
# LDOIJNDB_02260                          0.102126
# LDOIJNDB_02261                       1034.813125
# LDOIJNDB_02262                          0.104254
# LDOIJNDB_02263                        217.263360
#
#                 Pup_4-cecal_contents_53_1C_Pup_4  \
# target_id
# ANCJAENF_00001                       6355.334362
# ANCJAENF_00002                     119328.512453
# ANCJAENF_00003                       6355.334362
# ANCJAENF_00004                     119328.512453
# ANCJAENF_00005                          0.838482
# ...                                          ...
# LDOIJNDB_02259                          0.000000
# LDOIJNDB_02260                          0.108955
# LDOIJNDB_02261                       1162.256605
# LDOIJNDB_02262                          0.190671
# LDOIJNDB_02263                        144.180157
#
#                 Pup_5-cecal_contents_53_1C_Pup_5  \
# target_id
# ANCJAENF_00001                       5213.628480
# ANCJAENF_00002                      96049.853882
# ANCJAENF_00003                       5213.628480
# ANCJAENF_00004                      96049.853882
# ANCJAENF_00005                          0.162994
# ...                                          ...
# LDOIJNDB_02259                          0.000000
# LDOIJNDB_02260                          0.048657
# LDOIJNDB_02261                       1218.553802
# LDOIJNDB_02262                          0.305118
# LDOIJNDB_02263                        144.141776
#
#                 Pup_6-cecal_contents_53_1C_Pup_6  \
# target_id
# ANCJAENF_00001                       3051.344095
# ANCJAENF_00002                      69706.300016
# ANCJAENF_00003                       3051.344095
# ANCJAENF_00004                      69706.300016
# ANCJAENF_00005                          0.232979
# ...                                          ...
# LDOIJNDB_02259                          0.000000
# LDOIJNDB_02260                          0.026916
# LDOIJNDB_02261                        694.954622
# LDOIJNDB_02262                          0.199656
# LDOIJNDB_02263                         69.101055
#
#                 Pup_7-cecal_contents_53_1C_Pup_7  \
# target_id
# ANCJAENF_00001                       2877.279440
# ANCJAENF_00002                      47068.528300
# ANCJAENF_00003                       2877.279440
# ANCJAENF_00004                      47068.528300
# ANCJAENF_00005                          0.667122
# ...                                          ...
# LDOIJNDB_02259                          0.000000
# LDOIJNDB_02260                          0.039919
# LDOIJNDB_02261                        919.840761
# LDOIJNDB_02262                          0.056760
# LDOIJNDB_02263                        171.014892
#
#                 Pup_8-cecal_contents_53_1C_Pup_8  \
# target_id
# ANCJAENF_00001                       5582.569924
# ANCJAENF_00002                     104737.508090
# ANCJAENF_00003                       5582.569924
# ANCJAENF_00004                     104737.508090
# ANCJAENF_00005                          0.117242
# ...                                          ...
# LDOIJNDB_02259                          0.000000
# LDOIJNDB_02260                          0.025122
# LDOIJNDB_02261                       1133.894294
# LDOIJNDB_02262                          0.255539
# LDOIJNDB_02263                        214.868212
#
#                 Pup_1-cecal_contents_54_2B_Pup_1  \
# target_id
# ANCJAENF_00001                       7935.467468
# ANCJAENF_00002                     120582.208950
# ANCJAENF_00003                       7935.467468
# ANCJAENF_00004                     120582.208950
# ANCJAENF_00005                          1.561649
# ...                                          ...
# LDOIJNDB_02259                          0.000000
# LDOIJNDB_02260                          0.069623
# LDOIJNDB_02261                       1715.560181
# LDOIJNDB_02262                          0.403010
# LDOIJNDB_02263                        355.894021
#
#                 Pup_2-cecal_contents_54_2B_Pup_2  \
# target_id
# ANCJAENF_00001                       3352.167320
# ANCJAENF_00002                      45779.786352
# ANCJAENF_00003                       3352.167320
# ANCJAENF_00004                      45779.786352
# ANCJAENF_00005                          0.000000
# ...                                          ...
# LDOIJNDB_02259                          0.000000
# LDOIJNDB_02260                          0.220767
# LDOIJNDB_02261                       1311.712176
# LDOIJNDB_02262                          0.321952
# LDOIJNDB_02263                        132.391287
#
#                 Pup_3-cecal_contents_54_2B_Pup_3  \
# target_id
# ANCJAENF_00001                       2277.947107
# ANCJAENF_00002                      46320.455402
# ANCJAENF_00003                       2277.947107
# ANCJAENF_00004                      46320.455402
# ANCJAENF_00005                          0.000000
# ...                                          ...
# LDOIJNDB_02259                          0.000000
# LDOIJNDB_02260                          0.044953
# LDOIJNDB_02261                       1823.739361
# LDOIJNDB_02262                          0.167169
# LDOIJNDB_02263                        151.545135
#
#                 Pup_4-cecal_contents_54_2B_Pup_4  \
# target_id
# ANCJAENF_00001                        705.339424
# ANCJAENF_00002                      13465.515763
# ANCJAENF_00003                        705.339424
# ANCJAENF_00004                      13465.515763
# ANCJAENF_00005                          0.000000
# ...                                          ...
# LDOIJNDB_02259                          0.000000
# LDOIJNDB_02260                          0.227426
# LDOIJNDB_02261                       3460.840593
# LDOIJNDB_02262                          0.895488
# LDOIJNDB_02263                        447.156747
#
#                 Pup_5-cecal_contents_54_2B_Pup_5  \
# target_id
# ANCJAENF_00001                       1200.330028
# ANCJAENF_00002                      21372.914436
# ANCJAENF_00003                       1200.330028
# ANCJAENF_00004                      21372.914436
# ANCJAENF_00005                          1.730563
# ...                                          ...
# LDOIJNDB_02259                          0.000000
# LDOIJNDB_02260                          0.157428
# LDOIJNDB_02261                        449.344490
# LDOIJNDB_02262                          0.405735
# LDOIJNDB_02263                         59.408886
#
#                 Pup_6-cecal_contents_54_2B_Pup_6  \
# target_id
# ANCJAENF_00001                      22249.409698
# ANCJAENF_00002                     387117.537213
# ANCJAENF_00003                      22249.409698
# ANCJAENF_00004                     387117.537213
# ANCJAENF_00005                          0.000000
# ...                                          ...
# LDOIJNDB_02259                          0.000000
# LDOIJNDB_02260                          0.095594
# LDOIJNDB_02261                       6509.280243
# LDOIJNDB_02262                          0.192384
# LDOIJNDB_02263                       1790.401145
#
#                 Pup_7-cecal_contents_54_2B_Pup_7
# target_id
# ANCJAENF_00001                      13864.124597
# ANCJAENF_00002                     221018.827320
# ANCJAENF_00003                      13864.124597
# ANCJAENF_00004                     221018.827320
# ANCJAENF_00005                          3.458889
# ...                                          ...
# LDOIJNDB_02259                          0.000000
# LDOIJNDB_02260                          0.096899
# LDOIJNDB_02261                       2517.254234
# LDOIJNDB_02262                          0.604104
# LDOIJNDB_02263                        646.253898
#
# [48390 rows x 15 columns]
#                 Pup_1-cecal_contents_53_1C_Pup_1  \
# target_id
# ANCJAENF_00001                              5586
# ANCJAENF_00002                            108577
# ANCJAENF_00003                              5586
# ANCJAENF_00004                            108577
# ANCJAENF_00005                                 3
# ...                                          ...
# LDOIJNDB_02259                                 0
# LDOIJNDB_02260                                 0
# LDOIJNDB_02261                              1134
# LDOIJNDB_02262                                 0
# LDOIJNDB_02263                               229
#
#                 Pup_2-cecal_contents_53_1C_Pup_2  \
# target_id
# ANCJAENF_00001                              5174
# ANCJAENF_00002                            112351
# ANCJAENF_00003                              5174
# ANCJAENF_00004                            112351
# ANCJAENF_00005                                 1
# ...                                          ...
# LDOIJNDB_02259                                 0
# LDOIJNDB_02260                                 0
# LDOIJNDB_02261                              4701
# LDOIJNDB_02262                                 1
# LDOIJNDB_02263                               999
#
#                 Pup_3-cecal_contents_53_1C_Pup_3  \
# target_id
# ANCJAENF_00001                              3244
# ANCJAENF_00002                             88399
# ANCJAENF_00003                              3244
# ANCJAENF_00004                             88399
# ANCJAENF_00005                                 1
# ...                                          ...
# LDOIJNDB_02259                                 0
# LDOIJNDB_02260                                 0
# LDOIJNDB_02261                              1034
# LDOIJNDB_02262                                 0
# LDOIJNDB_02263                               217
#
#                 Pup_4-cecal_contents_53_1C_Pup_4  \
# target_id
# ANCJAENF_00001                              6355
# ANCJAENF_00002                            119328
# ANCJAENF_00003                              6355
# ANCJAENF_00004                            119328
# ANCJAENF_00005                                 0
# ...                                          ...
# LDOIJNDB_02259                                 0
# LDOIJNDB_02260                                 0
# LDOIJNDB_02261                              1162
# LDOIJNDB_02262                                 0
# LDOIJNDB_02263                               144
#
#                 Pup_5-cecal_contents_53_1C_Pup_5  \
# target_id
# ANCJAENF_00001                              5213
# ANCJAENF_00002                             96049
# ANCJAENF_00003                              5213
# ANCJAENF_00004                             96049
# ANCJAENF_00005                                 0
# ...                                          ...
# LDOIJNDB_02259                                 0
# LDOIJNDB_02260                                 0
# LDOIJNDB_02261                              1218
# LDOIJNDB_02262                                 0
# LDOIJNDB_02263                               144
#
#                 Pup_6-cecal_contents_53_1C_Pup_6  \
# target_id
# ANCJAENF_00001                              3051
# ANCJAENF_00002                             69706
# ANCJAENF_00003                              3051
# ANCJAENF_00004                             69706
# ANCJAENF_00005                                 0
# ...                                          ...
# LDOIJNDB_02259                                 0
# LDOIJNDB_02260                                 0
# LDOIJNDB_02261                               694
# LDOIJNDB_02262                                 0
# LDOIJNDB_02263                                69
#
#                 Pup_7-cecal_contents_53_1C_Pup_7  \
# target_id
# ANCJAENF_00001                              2877
# ANCJAENF_00002                             47068
# ANCJAENF_00003                              2877
# ANCJAENF_00004                             47068
# ANCJAENF_00005                                 0
# ...                                          ...
# LDOIJNDB_02259                                 0
# LDOIJNDB_02260                                 0
# LDOIJNDB_02261                               919
# LDOIJNDB_02262                                 0
# LDOIJNDB_02263                               171
#
#                 Pup_8-cecal_contents_53_1C_Pup_8  \
# target_id
# ANCJAENF_00001                              5582
# ANCJAENF_00002                            104737
# ANCJAENF_00003                              5582
# ANCJAENF_00004                            104737
# ANCJAENF_00005                                 0
# ...                                          ...
# LDOIJNDB_02259                                 0
# LDOIJNDB_02260                                 0
# LDOIJNDB_02261                              1133
# LDOIJNDB_02262                                 0
# LDOIJNDB_02263                               214
#
#                 Pup_1-cecal_contents_54_2B_Pup_1  \
# target_id
# ANCJAENF_00001                              7935
# ANCJAENF_00002                            120582
# ANCJAENF_00003                              7935
# ANCJAENF_00004                            120582
# ANCJAENF_00005                                 1
# ...                                          ...
# LDOIJNDB_02259                                 0
# LDOIJNDB_02260                                 0
# LDOIJNDB_02261                              1715
# LDOIJNDB_02262                                 0
# LDOIJNDB_02263                               355
#
#                 Pup_2-cecal_contents_54_2B_Pup_2  \
# target_id
# ANCJAENF_00001                              3352
# ANCJAENF_00002                             45779
# ANCJAENF_00003                              3352
# ANCJAENF_00004                             45779
# ANCJAENF_00005                                 0
# ...                                          ...
# LDOIJNDB_02259                                 0
# LDOIJNDB_02260                                 0
# LDOIJNDB_02261                              1311
# LDOIJNDB_02262                                 0
# LDOIJNDB_02263                               132
#
#                 Pup_3-cecal_contents_54_2B_Pup_3  \
# target_id
# ANCJAENF_00001                              2277
# ANCJAENF_00002                             46320
# ANCJAENF_00003                              2277
# ANCJAENF_00004                             46320
# ANCJAENF_00005                                 0
# ...                                          ...
# LDOIJNDB_02259                                 0
# LDOIJNDB_02260                                 0
# LDOIJNDB_02261                              1823
# LDOIJNDB_02262                                 0
# LDOIJNDB_02263                               151
#
#                 Pup_4-cecal_contents_54_2B_Pup_4  \
# target_id
# ANCJAENF_00001                               705
# ANCJAENF_00002                             13465
# ANCJAENF_00003                               705
# ANCJAENF_00004                             13465
# ANCJAENF_00005                                 0
# ...                                          ...
# LDOIJNDB_02259                                 0
# LDOIJNDB_02260                                 0
# LDOIJNDB_02261                              3460
# LDOIJNDB_02262                                 0
# LDOIJNDB_02263                               447
#
#                 Pup_5-cecal_contents_54_2B_Pup_5  \
# target_id
# ANCJAENF_00001                              1200
# ANCJAENF_00002                             21372
# ANCJAENF_00003                              1200
# ANCJAENF_00004                             21372
# ANCJAENF_00005                                 1
# ...                                          ...
# LDOIJNDB_02259                                 0
# LDOIJNDB_02260                                 0
# LDOIJNDB_02261                               449
# LDOIJNDB_02262                                 0
# LDOIJNDB_02263                                59
#
#                 Pup_6-cecal_contents_54_2B_Pup_6  \
# target_id
# ANCJAENF_00001                             22249
# ANCJAENF_00002                            387117
# ANCJAENF_00003                             22249
# ANCJAENF_00004                            387117
# ANCJAENF_00005                                 0
# ...                                          ...
# LDOIJNDB_02259                                 0
# LDOIJNDB_02260                                 0
# LDOIJNDB_02261                              6509
# LDOIJNDB_02262                                 0
# LDOIJNDB_02263                              1790
#
#                 Pup_7-cecal_contents_54_2B_Pup_7
# target_id
# ANCJAENF_00001                             13864
# ANCJAENF_00002                            221018
# ANCJAENF_00003                             13864
# ANCJAENF_00004                            221018
# ANCJAENF_00005                                 3
# ...                                          ...
# LDOIJNDB_02259                                 0
# LDOIJNDB_02260                                 0
# LDOIJNDB_02261                              2517
# LDOIJNDB_02262                                 0
# LDOIJNDB_02263                               646
#
# [48390 rows x 15 columns]

# %%
# print(len(count_df.columns))
